# %% [markdown]
# # T3.2 Analizar e visualizar estatísticas de datos baixados de MongoDB
# ## Conexión a MongoDB dende Python e análise de datos

# %% [markdown]
# En Atlas mete o dataset de exemplo na túa base de datos.
#
# Engade o enderezo IP autorizado a conectar para que poidas conectar á base de datos.
#
# Proba a conectar dende compass coa URL de conexión que che da.
#
# Da BBDD de proba: sample_mfix, na colección movies: https://www.mongodb.com/docs/atlas/sample-data/sample-mflix/

# %% [markdown]
# Conecta a Atlas dende Python, carga a colección en Pandas. Averigua o modo máis adecuado.

# %% [markdown]
# ### Instalación das librarías necesarias
# - pymongo
# - dnspython

# %%
# !conda install -y pymongo dnspython
# Out:
# ^C

# %% [markdown]
# ### Conexión cas bases de datos

# %%
from pymongo import MongoClient

HOST=f"mongodb+srv://daniel:<password>@danielm.bmmrbec.mongodb.net/"
PORT=27017
USERNAME="daniel"
PASSWORD="6H8QiZIHLt7qylbr"


if HOST == 'localhost':
    if not USERNAME:
        cli_mongo = MongoClient(HOST, PORT)
    else:
        cli_mongo = MongoClient(HOST, PORT, USERNAME, PASSWORD)
else:
    cli_mongo = MongoClient(f"mongodb+srv://daniel:{PASSWORD}@danielm.bmmrbec.mongodb.net/")

# %% [markdown]
# ### Importación de librerías

# %%
import pandas as pd

# %% [markdown]
# ### Listado das bases de datos existentes

# %%
print (cli_mongo.list_database_names())
# Out:
# ['covid', 'sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %% [markdown]
# ### Conexión ca base de datos ca que se traballará

# %%
db_movies=cli_mongo['sample_mflix']

# Listado das coleccións da base de datos
print (db_movies.list_collection_names())
# Out:
# ['sessions', 'embedded_movies', 'users', 'movies', 'theaters', 'comments']

# %% [markdown]
# ### Convertir a colección 'movies' en un dataframe de Pandas

# %%
coleccion_nombre = db_movies.movies

# Obtención de todos os documentos da colección
cursor = coleccion_nombre.find()
# Conversión do cursor a lista
list_cur = list(cursor)
# Conversión a DataFrame
df_movies = pd.DataFrame(list_cur)

df_movies.head()
# Out:
#                         _id  \
# 0  573a1390f29313caabcd446f
# 1  573a1390f29313caabcd5a93
# 2  573a1390f29313caabcd5ea4
# 3  573a1390f29313caabcd6377
# 4  573a1391f29313caabcd6e2a
#
#                                                 plot  \
# 0  A greedy tycoon decides, on a whim, to corner ...
# 1  Christ takes on the form of a pacifist count t...
# 2  A District Attorney's outspoken stand on abort...
# 3  A rich young Easterner who has always wanted t...
# 4  A newly wedded couple attempt to build a house...
#
#                        genres  runtime  \
# 0              [Short, Drama]     14.0
# 1                     [Drama]     78.0
# 2                     [Drama]     62.0
# 3  [Comedy, Western, Romance]     72.0
# 4             [Short, Comedy]     25.0
#
#                                                 cast  num_mflix_comments  \
# 0  [Frank Powell, Grace Henderson, James Kirkwood...                   1
# 1  [Howard C. Hickman, Enid Markey, Lola May, Kat...                   0
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21349 entries, 0 to 21348
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 21349 non-null  object
#  1   plot                20203 non-null  object
#  2   genres              21237 non-null  object
#  3   runtime             20910 non-null  float64
#  4   cast                20987 non-null  object
#  5   num_mflix_comments  21349 non-null  int64
#  6   title               21349 non-null  object
#  7   fullplot            19852 non-null  object
#  8   languages           21119 non-null  object
#  9   released            20878 non-null  datetime64[ns]
#  10  directors           21107 non-null  object
#  11  rated               11455 non-null  object
#  12  awards              21349 non-null  object
#  13  lastupdated         21349 non-null  object
#  14  year                21349 non-null  object
# ...

# %%
df_movies.columns
# Out:
# Index(['_id', 'plot', 'genres', 'runtime', 'cast', 'num_mflix_comments',
#        'title', 'fullplot', 'languages', 'released', 'directors', 'rated',
#        'awards', 'lastupdated', 'year', 'imdb', 'countries', 'type',
#        'tomatoes', 'poster', 'writers', 'metacritic'],
#       dtype='object')

# %% [markdown]
# A) Contar o total de películas.

# %%
total_peliculas = df_movies["title"].count()
print(f"Total de películas: {total_peliculas}")
# Out:
# Total de películas: 21349

# %% [markdown]
# B) Contar o número de películas de cada xénero.

# %%
# Os valores da columna 'genres' son listas
generos_peliculas = {}
# Hai que borrar os Nan para que non de fallo na iteración
generos = df_movies["genres"].dropna().tolist()


for i in generos:
    for genero in i:
        if len(generos_peliculas) == 0:
            generos_peliculas[genero] = 1
        # Si o xénero está dentro do listado
        elif genero in generos_peliculas.keys():
            generos_peliculas[genero] += 1
        else:
            # Si o xénero NON está dentro do listado
            generos_peliculas[genero] = 1

df_gen_num = pd.DataFrame.from_dict(generos_peliculas, orient="index", columns=["num_peliculas"])
df_gen_num
# Out:
#              num_peliculas
# Short                  442
# Drama                12385
# Comedy                6532
# Western                242
# Romance               3318
# Thriller              2454
# Adventure             1900
# Family                1249
# Fantasy               1055
# Action                2381
# Musical                440
# Biography             1269
# History                874
# Animation              912
# Music                  780
# Sport                  366
# Crime                 2457
# War                    699
# Horror                1470
# Mystery               1139
# Sci-Fi                 958
# Film-Noir               77
# Documentary           1834
# Talk-Show                1
# News                    44

# %% [markdown]
# C) Contar cantas películas hai por ano.

# %%
anho_peliculas = df_movies.groupby("year").size()
anio_peliculas = anho_peliculas.to_frame(name="num_peliculas").sort_values("num_peliculas", ascending=False)
anio_peliculas
# Out:
#        num_peliculas
# year
# 2013            1105
# 2014            1073
# 2012             955
# 2009             917
# 2011             893
# ...              ...
# 1987è              1
# 1986è              1
# 1981è              1
# 2016               1
# 2000è              1
#
# [130 rows x 1 columns]

# %% [markdown]
# D) Mirar se hai correlación entre imdb e rotten tomatoes.

# %%
df_movies["tomatoes"].dropna(ignore_index=True) # "ignore_index" para no cortar los índices
# Out:
# 0        {'viewer': {'rating': 3.6, 'numReviews': 109, ...
# 1        {'viewer': {'rating': 0.0, 'numReviews': 7}, '...
# 2        {'viewer': {'rating': 3.1, 'numReviews': 34, '...
# 3        {'viewer': {'rating': 4.3, 'numReviews': 752, ...
# 4        {'viewer': {'rating': 2.5, 'numReviews': 2}, '...
#                                ...
# 18583    {'website': 'http://www.thunderandthehouseofma...
# 18584    {'viewer': {'rating': 0.0, 'numReviews': 0}, '...
# 18585    {'viewer': {'rating': 4.2, 'numReviews': 37}, ...
# 18586    {'viewer': {'rating': 5.0, 'numReviews': 5}, '...
# 18587    {'website': 'http://www.tinpanfilms.com/', 'vi...
# Name: tomatoes, Length: 18588, dtype: object

# %%
df_movies["tomatoes"][20]
# Out:
# {'viewer': {'rating': 3.3, 'numReviews': 70, 'meter': 50},
#  'lastUpdated': datetime.datetime(2015, 7, 24, 19, 6, 28)}

# %%
df_movies["imdb"][6]
# Out:
# {'rating': 7.3, 'votes': 1777, 'id': 13140}

# %%
tomatoe_viewer_rating = {}
tomatoe_viewer_numReviews = {}

list_tomatoes = df_movies["tomatoes"].dropna().to_list()
list_tomatoes[0]["viewer"]
idx = -1

for i in list_tomatoes:
    idx += 1
    try:
        tomatoe_viewer_rating[i["viewer"]["rating"]] = idx
        tomatoe_viewer_numReviews[i["viewer"]["numReviews"]] = idx
    except KeyError:
        continue
# Out:
# 8562 45

# %% [markdown]
# E) Contar cantas películas ten cada director

# %%
# Borro rexistros nan
lista_directores = df_movies["directors"].dropna().tolist()

directores_peliculas = {}


for i in lista_directores:
    # Hai valores de tipo float en algúns registros da columna "directors", entonces procederase a recoller os rexistros con listas de directores só
    if isinstance(i, list):
        if len(i) == 1:
            if i[0] in directores_peliculas.keys():
                directores_peliculas[i[0]] += 1
            else:
                directores_peliculas[i[0]] = 1
        else:
            for idx in i:
                if idx in directores_peliculas.keys():
                    directores_peliculas[idx] += 1
                else:
                    directores_peliculas[idx] = 1
            

directores_peliculas = pd.DataFrame.from_dict(directores_peliculas, orient="index", columns=["num_peliculas"]).sort_values("num_peliculas", ascending=False)
directores_peliculas

# Unha maneira de eliminar as filas cuxos rexistros da correspondente columna "directors" foran float: 
# df_movies = df_movies.loc[~df_movies["directors"].isin([float])]
# Out:
#                      num_peliculas
# Woody Allen                     40
# Martin Scorsese                 32
# Takashi Miike                   31
# Sidney Lumet                    29
# Steven Spielberg                29
# ...                            ...
# Michael John Warren              1
# Patrick Paulson                  1
# Diego Rafecas                    1
# Timothy Bond                     1
# Visar Morina                     1
#
# [10843 rows x 1 columns]

# %% [markdown]
# F) Contar en cantas películas ten participado cada actor

# %%
import numpy as np
listas_actores = df_movies["cast"].dropna().tolist()

df_movies[df_movies["cast"] == np.nan]
# Out:
# Empty DataFrame
# Columns: [_id, plot, genres, runtime, cast, num_mflix_comments, title, fullplot, languages, released, directors, rated, awards, lastupdated, year, imdb, countries, type, tomatoes, poster, writers, metacritic]
# Index: []
#
# [0 rows x 22 columns]

# %%
dict_peliculas_actores = {}
for i in listas_actores:
    for idx in i:
        if len(dict_peliculas_actores) == 0:
            dict_peliculas_actores[idx] = 1
        else:
            if idx in dict_peliculas_actores.keys():
                dict_peliculas_actores[idx] += 1
            else:
                dict_peliculas_actores[idx] = 1

dict_peliculas_actores = pd.DataFrame.from_dict(dict_peliculas_actores, orient="index", columns=["num_peliculas"]).sort_values("num_peliculas", ascending=False)
dict_peliculas_actores
# Out:
#                       num_peliculas
# Gèrard Depardieu                 67
# Robert De Niro                   58
# Michael Caine                    51
# Bruce Willis                     49
# Morgan Freeman                   48
# ...                             ...
# Chandrakant Kulkarni              1
# Ralph Eggleston                   1
# Marie Bèumer                      1
# Sibylle Canonica                  1
# Enver Petrovci                    1
#
# [38636 rows x 1 columns]

# %% [markdown]
# G) Contar cantas películas hai de cada idioma

# %%
lista_idiomas = df_movies["languages"].dropna().tolist()
lista_idiomas
# Out:
# [['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', 'Russian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', 'Russian'],
#  ['German'],
#  ['English'],
#  ['English'],
#  ['English', 'Italian', 'Russian', 'Spanish', 'German'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['French'],
#  ['German'],
#  ['Russian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Russian'],
#  ['English'],
#  ['English'],
#  ['English', 'Spanish', 'Italian'],
#  ['English', 'French'],
#  ['English', 'French', 'Spanish', 'Arabic', 'Italian'],
#  ['English'],
#  ['English'],
#  ['English'],
# ...

# %%
dict_idiomas_peliculas = {}

for i in lista_idiomas:
    for idx in i:
        if len(dict_idiomas_peliculas) == 0:
            dict_idiomas_peliculas[idx] = 1
        else:
            if idx in dict_idiomas_peliculas.keys():
                dict_idiomas_peliculas[idx] += 1
            else:
                dict_idiomas_peliculas[idx] = 1

dict_idiomas_peliculas = pd.DataFrame.from_dict(dict_idiomas_peliculas, orient="index", columns=["num_peliculas"]).sort_values("num_peliculas", ascending=False)
dict_idiomas_peliculas
# Out:
#                num_peliculas
# English                14639
# French                  2405
# Spanish                 1600
# German                  1377
# Italian                 1228
# ...                      ...
# Tonga                      1
# Nenets                     1
# Tuvinian                   1
# Luxembourgish              1
# Tigrigna                   1
#
# [231 rows x 1 columns]

# %% [markdown]
# H) Cal é a media de premios das películas

# %%
# Cada rexistro da columna asemella que non ten ningunha variación na estructura de gardar os datos.
df_movies["awards"][11000]
# Out:
# {'wins': 8, 'nominations': 16, 'text': '8 wins & 16 nominations.'}

# %%
# Vemos que a columna é unha lista de diccionarios
lista_premios = df_movies["awards"].to_list()
lista_premios
# Out:
# [{'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#  {'wins': 0, 'nominations': 3, 'text': 'Won 1 Oscar. Another 2 nominations.'},
#  {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  {'wins': 2,
#   'nominations': 2,
# ...

# %%
from statistics import mean 
lista_num_premios = []

# Obtemos todos os premios de cada película, para despois calcular a media.
for i in lista_premios:
    lista_num_premios.append(i["wins"])

media_premios = mean(lista_num_premios)
print(f"A media de premios das películas é {round(media_premios, 2)}")
# Out:
# A media de premios das películas é 4.06

# %% [markdown]
# J) Amosar as películas que teñen alomenos 3 premios

# %%
indices = []
idx = -1
for i in lista_premios:
    idx += 1
    if i["wins"] >= 3:
        indices.append(idx)

indices
# Out:
# [24,
#  59,
#  60,
#  63,
#  64,
#  65,
#  70,
#  84,
#  91,
#  93,
#  96,
#  97,
#  100,
#  108,
#  112,
#  115,
#  118,
#  142,
#  145,
#  152,
#  153,
#  158,
#  160,
#  163,
#  169,
#  170,
#  172,
#  175,
#  181,
#  183,
#  184,
#  187,
#  192,
#  194,
#  195,
#  197,
#  204,
#  206,
#  207,
#  212,
#  217,
#  219,
#  222,
#  223,
#  226,
#  229,
#  233,
#  237,
#  241,
#  242,
#  246,
#  248,
#  261,
#  262,
#  268,
#  269,
#  281,
#  282,
#  291,
#  300,
#  301,
#  302,
#  313,
#  314,
#  315,
#  317,
#  319,
#  320,
#  321,
#  324,
#  328,
#  331,
#  332,
#  335,
#  343,
#  345,
#  346,
#  351,
#  352,
#  354,
#  356,
#  358,
#  361,
#  362,
#  369,
#  375,
#  379,
#  387,
#  398,
#  402,
#  403,
#  404,
#  405,
#  406,
#  409,
#  411,
#  412,
#  413,
#  419,
#  423,
#  424,
#  432,
#  433,
#  435,
#  449,
#  452,
#  456,
#  457,
#  458,
#  463,
#  465,
#  474,
#  476,
#  477,
#  479,
#  480,
#  481,
#  484,
#  486,
#  487,
#  492,
#  505,
#  506,
#  512,
#  514,
#  516,
# ...

# %%
pelis_premiadas = df_movies.loc[indices]
print("Películas con 3 ou máis premios:")


nombre_pelis_premiadas = pelis_premiadas['title'].to_list()

for i in nombre_pelis_premiadas:
    print(f"\t- {i}")
# Out:
# Películas con 3 ou máis premios:
# 	- City Lights
# 	- Morocco
# 	- Romance
# 	- The Sin of Madelon Claudet
# 	- Tabu: A Story of the South Seas
# 	- è Nous la Libertè
# 	- Cavalcade
# 	- David Copperfield
# 	- Napoleon
# 	- Wings
# 	- The Guardsman
# 	- Mèdchen in Uniform
# 	- Dr. Jekyll and Mr. Hyde
# 	- She Done Him Wrong
# 	- One Night of Love
# 	- Viva Villa!
# 	- Alice Adams
# 	- Cimarron
# 	- The Front Page
# 	- State Fair
# 	- The Barretts of Wimpole Street
# 	- Imitation of Life
# 	- Man of Aran
# 	- Anna Karenina
# 	- Top Hat
# 	- Who Killed Cock Robin?
# 	- The Garden of Allah
# 	- Romeo and Juliet
# 	- Snow White and the Seven Dwarfs
# 	- The Adventures of Robin Hood
# 	- Angels with Dirty Faces
# 	- Four Daughters
# 	- Sweethearts
# 	- Vivacious Lady
# 	- Dark Victory
# 	- Gone with the Wind
# 	- Pinocchio
# 	- Citizen Kane
# 	- Les Misèrables
# 	- Dodsworth
# 	- Captains Courageous
# 	- The Good Earth
# 	- The Prisoner of Zenda
# 	- Dance Program
# 	- Jezebel
# ...

# %% [markdown]
# K) Contar as películas por país

# %%
lista_paises = df_movies["countries"].to_list()
dict_paises = {}

for i in lista_paises:
    # Filtramos só os datos que sean una lista de países
    if isinstance(i,list):
        for pais in i:
            # Filtramos os datos para que non se cole outro tipo de dato que non sea un string
            if isinstance(pais, str):
                if len(dict_paises) == 0:
                    dict_paises[pais] = 1
                else:
                    if pais in dict_paises.keys():
                        dict_paises[pais] += 1
                    else:
                        dict_paises[pais] = 1

dict_paises = pd.DataFrame.from_dict(dict_paises, orient="index", columns=["num_peliculas"]).sort_values("num_peliculas", ascending=False)
dict_paises
# Out:
#                num_peliculas
# USA                    10921
# UK                      2652
# France                  2647
# Germany                 1494
# Canada                  1260
# ...                      ...
# Zimbabwe                   1
# Faroe Islands              1
# Aruba                      1
# Gabon                      1
# Vanuatu                    1
#
# [158 rows x 1 columns]
