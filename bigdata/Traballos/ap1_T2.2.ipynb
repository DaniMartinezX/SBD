# %%
import pandas as pd
import os

path_file = 'C:/Users/daniel.martinezcarre/Desktop/Clase/bigdata/profesores_sus.xlsx'

dfProfesores = pd.read_excel(path_file)

dfProfesores.head()
# Out:
#      Data alta centro   Data adxudicación   Teléfono  \
# 0 2023-11-07 13:51:00 2023-11-28 14:02:00  881960260
# 1 2023-11-06 12:00:00 2023-11-07 10:35:00  881867126
# 2 2023-10-03 18:23:00 2023-10-06 13:06:00  881960260
# 3 2023-09-20 12:36:00 2023-09-25 18:16:00  881867501
# 4 2023-09-06 19:49:00 2023-09-25 18:36:00  881960101
#
#                                               Centro  \
# 0    15005397 - IES Fernando Wirtz Suárez (A Coruña)
# 1         15026391 - IES Xulián Magariños (Negreira)
# 2    15005397 - IES Fernando Wirtz Suárez (A Coruña)
# 3  15021482 - IES San Clemente (Santiago de Compo...
# 4               15021755 - IES Cabo Ortegal (Cariño)
#
#                        Especialidade/Modalidade Lingua da praza   Xornada  \
# 0  590227 - Sistemas e aplicacións informáticas    Non bilingüe  Completa
# 1  590227 - Sistemas e aplicacións informáticas    Non bilingüe  Completa
# 2  590227 - Sistemas e aplicacións informáticas    Non bilingüe  Completa
# ...

# %%
dfProfesores['Codigo_centro'] = dfProfesores['Centro'].str.split(' - ').str[0]
dfProfesores['Centro'] = dfProfesores['Centro'].str.split(' - ').str[1]
dfProfesores.head()
# Out:
#      Data alta centro   Data adxudicación   Teléfono  \
# 0 2023-11-07 13:51:00 2023-11-28 14:02:00  881960260
# 1 2023-11-06 12:00:00 2023-11-07 10:35:00  881867126
# 2 2023-10-03 18:23:00 2023-10-06 13:06:00  881960260
# 3 2023-09-20 12:36:00 2023-09-25 18:16:00  881867501
# 4 2023-09-06 19:49:00 2023-09-25 18:36:00  881960101
#
#                                       Centro  \
# 0       IES Fernando Wirtz Suárez (A Coruña)
# 1            IES Xulián Magariños (Negreira)
# 2       IES Fernando Wirtz Suárez (A Coruña)
# 3  IES San Clemente (Santiago de Compostela)
# 4                  IES Cabo Ortegal (Cariño)
#
#                        Especialidade/Modalidade Lingua da praza   Xornada  \
# 0  590227 - Sistemas e aplicacións informáticas    Non bilingüe  Completa
# 1  590227 - Sistemas e aplicacións informáticas    Non bilingüe  Completa
# 2  590227 - Sistemas e aplicacións informáticas    Non bilingüe  Completa
# ...
